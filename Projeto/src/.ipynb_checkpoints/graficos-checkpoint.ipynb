# %%
import numpy as np
import pandas as pd
import seaborn as sns
import regression as reg

# %%
user_df = pd.read_csv('dataframes/users_variables.csv')
user_df
# Out:
#              id  total_hours_played  size  games_played
# 0      54103616            0.331723   0.0            21
# 1     102825821            0.151575   0.0            79
# 2      52907921            0.132780   0.0            34
# 3     215160630            0.112383   0.0            30
# 4     131940023            0.373976   0.0            52
# ...         ...                 ...   ...           ...
# 1036  125699277            0.007350   0.0             1
# 1037  109458201            0.050043   0.0             3
# 1038  198314976            0.000000   0.0             1
# 1039  252507011            0.000103   0.0             1
# 1040  301432974            0.005542   0.0             1
#
# [1041 rows x 4 columns]

# %%
games_df = pd.read_csv('dataframes/games_variables.csv')
games_df
# Out:
#                                                   Games  Cópias vendidas  \
# 0     1... 2... 3... KICK IT! (Drop That Beat Like a...                1
# 1                                     100% Orange Juice                2
# 2                                12 Labours of Hercules                1
# 3             12 Labours of Hercules II The Cretan Bull                5
# 4                 12 Labours of Hercules III Girl Power                2
# ...                                                 ...              ...
# 2931                                           realMyst                2
# 2932                      resident evil 4 / biohazard 4                6
# 2933                                       sZone-Online               10
# 2934                          the static speaks my name                2
# 2935                                          theHunter               32
#
#       Hours Played  Número de jogadores     _merge  Popularidade  Temp Med  \
# ...

# %% [markdown]
# ## MODELO A

# %%
sns.scatterplot(x=games_df['Temp Med'], y=games_df['Popularidade']);

# %%
sns.regplot(x=games_df['Temp Med'], y=games_df['Popularidade']);

# %% [markdown]
# ## MODELO B

# %%
sns.scatterplot(x=games_df['Jogadores por cópias'], y=games_df['Popularidade']);
